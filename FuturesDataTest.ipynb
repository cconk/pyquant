# %%
import yfinance as yf

# Fetch historical data
es = yf.Ticker("ES=F")
data = es.history(period="1y")  # Last 1 year
print(data)
# Out:
#                               Open     High      Low    Close   Volume  \
# Date
# 2024-01-02 00:00:00-05:00  4818.00  4828.00  4765.50  4787.25  1678142
# 2024-01-03 00:00:00-05:00  4790.75  4790.75  4741.00  4746.50  1707174
# 2024-01-04 00:00:00-05:00  4750.00  4766.50  4727.00  4729.50  1395366
# 2024-01-05 00:00:00-05:00  4732.75  4760.25  4702.00  4734.75  1767245
# 2024-01-08 00:00:00-05:00  4735.75  4803.25  4715.25  4801.25  1417728
# ...                            ...      ...      ...      ...      ...
# 2024-12-23 00:00:00-05:00  6001.75  6043.00  5965.00  6036.00  1406019
# 2024-12-24 00:00:00-05:00  6037.75  6099.50  6030.00  6098.00   634201
# 2024-12-26 00:00:00-05:00  6099.25  6107.50  6063.25  6095.25   911486
# 2024-12-27 00:00:00-05:00  6092.00  6095.25  5982.75  6027.00   911486
# 2024-12-30 00:00:00-05:00  5955.00  5955.00  5944.00  5952.50     6917
#
#                            Dividends  Stock Splits
# Date
# ...
